# %% [markdown]
# ### Importing the modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("/content/wine_data.csv",usecols=[0,1,2],header=None)

# %%
df
# Out:
#      0      1     2
# 0    1  14.23  1.71
# 1    1  13.20  1.78
# 2    1  13.16  2.36
# 3    1  14.37  1.95
# 4    1  13.24  2.59
# ..  ..    ...   ...
# 173  3  13.71  5.65
# 174  3  13.40  3.91
# 175  3  13.27  4.28
# 176  3  13.17  2.59
# 177  3  14.13  4.10
#
# [178 rows x 3 columns]

# %%
df.columns = ["Class label","Alcohol","Malic acid"]

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %% [markdown]
# ### Kdeplot for independent features

# %%
sns.kdeplot(df["Alcohol"])

# %%
sns.kdeplot(df["Malic acid"])

# %% [markdown]
# ### Scatter Plot between independent features

# %%
sns.scatterplot(df["Alcohol"],df["Malic acid"],hue=df["Class label"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Separate independent and dependent features

# %%
X = df.drop("Class label",axis=1)
y = df["Class label"]

# %% [markdown]
# ### Train Test Split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Feature Scaling

# %%
sc = MinMaxScaler()

# %%
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    142.0       142.0
# mean      13.0         2.4
# std        0.8         1.2
# min       11.0         0.9
# 25%       12.3         1.5
# 50%       13.0         1.8
# 75%       13.6         3.2
# max       14.8         5.8

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    142.0       142.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.3         0.1
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %% [markdown]
# ### Before Scaling vs After Scaling

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].set_title("Before Scaling")
sns.scatterplot(X_train["Alcohol"],X_train["Malic acid"],hue=df["Class label"],ax=ax[0])
ax[1].set_title("After Scaling")
sns.scatterplot(X_train_scaled["Alcohol"],X_train_scaled["Malic acid"],hue=df["Class label"],ax=ax[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Kde Plot for independent features Before Scaling vs After Scaling

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].set_title("Before Scaling")
sns.kdeplot(X_train["Alcohol"],ax=ax[0])
sns.kdeplot(X_train["Malic acid"],ax=ax[0])
ax[1].set_title("After Scaling")
sns.kdeplot(X_train_scaled["Alcohol"],ax=ax[1])
sns.kdeplot(X_train_scaled["Malic acid"],ax=ax[1])

# %% [markdown]
# ### Kde Plot for Alcohol Before Scaling vs After Scaling

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].set_title("Alcohol Before Scaling")
sns.kdeplot(X_train["Alcohol"],ax=ax[0])
ax[1].set_title("Alcohol After Scaling")
sns.kdeplot(X_train_scaled["Alcohol"],ax=ax[1])

# %% [markdown]
# ### Kde Plot for Malic Acid Before Scaling vs After Scaling

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].set_title("Malic Acid Before Scaling")
sns.kdeplot(X_train["Malic acid"],ax=ax[0])
ax[1].set_title("Malic Acid After Scaling")
sns.kdeplot(X_train_scaled["Malic acid"],ax=ax[1])
